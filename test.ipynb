# %%
#read csv spesa.csv
import pandas as pd
df = pd.read_csv("data/spesa_v4.csv")

# %%
df
# Out:
#                            _id    rata   ente  \
# 0     65ee5ac5f458af56d2af532f  202402  867.0
# 1     668f34120377f62206882cd8  202406  921.0
# 2     66e0ee64f458af54a5dbc7fa  202408    9.0
# 3     663ec5eb3f62190222cfb590  202404   12.0
# 4     6731590c568f146446645d59  202410  910.0
# ...                        ...     ...    ...
# 7498  663ec5f43f62190222cfb73d  202404    7.0
# 7499  65ee5ac5f458af56d2af52cc  202402  912.0
# 7500  65c81f2c3f62191d310d64c7  202401  925.0
# 7501  668f34079b1c1405cffd2cb7  202406  834.0
# 7502  659f41729b1c1468e2e399b1  202312  829.0
#
#                                             descrizione  cod_tipoimposta  \
# 0                   AGENZIA ITALIANA DEL FARMACO - AIFA                2
# 1                           A.O. S. GIOVANNI ADDOLORATA                3
# 2                             MINISTERO DELLA GIUSTIZIA                4
# 3                                MINISTERO DELL'INTERNO                2
# ...
