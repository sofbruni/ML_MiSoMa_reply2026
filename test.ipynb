# %%
#read csv spesa.csv
import pandas as pd
df = pd.read_csv("data/attivazioniCessazioni_v4.csv")

# %%
df
# Out:
#        mese    anno  codice_ente  \
# 0      11.0  2023.0         19.0
# 1       7.0  2023.0       2020.0
# 2       8.0  2021.0       2020.0
# 3       4.0  2023.0       2020.0
# 4       6.0  2023.0         22.0
# ...     ...     ...          ...
# 20028   7.0  2023.0         10.0
# 20029   4.0  2023.0         10.0
# 20030   5.0  2023.0          9.0
# 20031   9.0  2023.0         14.0
# 20032   8.0  2023.0         32.0
#
#                                        descrizione_ente provincia_sede  \
# 0                       MINISTERO UNIVERSITA' E RICERCA             TO
# 1      MINISTERO DELL'INTERNO - DIPARTIMENTO DELLA P.S.             BT
# 2      MINISTERO DELL'INTERNO - DIPARTIMENTO DELLA P.S.             AQ
# 3      MINISTERO DELL'INTERNO - DIPARTIMENTO DELLA P.S.             AQ
# 4                                 AGENZIA DELLE ENTRATE             VR
# ...                                                 ...            ...
# ...
