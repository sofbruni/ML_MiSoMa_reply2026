# %%
import pandas as pd

#read csv in data/spesa.csv
df = pd.read_csv("data/spesa_v4.csv")

#show aggregation_time column
dc = df["aggregation_time"]

# %%
dc
# Out:
# 0       2024-03-11
# 1       2024-07-11
# 2       2024-09-11
# 3       2024-05-11
# 4       2024-11-11
#            ...
# 7497    2024-05-11
# 7498    2024-03-11
# 7499    2024-02-11
# 7500    2024-07-11
# 7501    2024-01-11
# Name: aggregation_time, Length: 7502, dtype: object
